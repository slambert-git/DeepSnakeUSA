# %%
import torch
print(torch.__version__)
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torchvision.datasets as datasets
import pdb
# Out:
# 1.0.1.post2

# %%
trans = torchvision.transforms.Compose([torchvision.transforms.ToTensor(), torchvision.transforms.Normalize((0.1307,), (0.3081,))])

mnist_trainset = datasets.MNIST(root='./data',train=True,download=True,transform=trans)
mnist_testset = datasets.MNIST(root='./data', train=False, download=True, transform=trans)

# %%
#Let's define some architecture dimensions

#batch size
bs=1000
#dimension of input layer
di=784 #28x28 flattened
#dimensions of hidden layers
dh=30
#dimension of output layer
do=10

# %%
#define a loss function
loss_fn=torch.nn.CrossEntropyLoss()

# %%
#define a dataloader
dl=torch.utils.data.DataLoader(mnist_trainset,batch_size=bs,shuffle=True,num_workers=0)
dl_test=torch.utils.data.DataLoader(mnist_testset,batch_size=bs,shuffle=True,num_workers=0)

# %%
#look at some data
examples=enumerate(dl_test)
batch_id, (x,y) = next(examples)
x.shape

# %%
#Option 1: Using nn.Sequential to define architecture
seqmodel=torch.nn.Sequential(
     torch.nn.Linear(di,dh),
     torch.nn.ReLU(),
     torch.nn.Linear(dh,dh),
     torch.nn.ReLU(),
     torch.nn.Linear(dh,dh),
     torch.nn.ReLU(),
     torch.nn.Linear(dh,do)
)

# %%
#Set optimizier and lr for training loop
lr=1e-3
optimizer=torch.optim.Adam(seqmodel.parameters(),lr=lr)

# %%
#Define training loop
#for epochs:
for e in range(10):
  print('EPOCH ',e,loss.item())
  #for batches:
  for batch_id, (x,y) in enumerate(dl):
    pdb.set_trace()
    #predict using network
    #have to flatten the input here. Seems like there should be a better way to read in the data to avoid this. 
    y_pred=seqmodel(x.view(x.size(0), -1))
    #compute loss 
    loss=loss_fn(y_pred,y)
    #print(batch_id, loss.item())
    #zero gradients
    optimizer.zero_grad()
    #backward pass
    loss.backward()
    #update params
    optimizer.step()
# Out:
# EPOCH  0 0.023710304871201515
# > <ipython-input-77-14937a3aeb5a>(8)<module>()->None
# -> y_pred=seqmodel(x.view(x.size(0), -1))
# (Pdb) x.shape()
# *** TypeError: 'torch.Size' object is not callable
# (Pdb) x.view(x.size(0), -1).shape
# torch.Size([1000, 784])
# (Pdb) x.numel()
# 784000
# (Pdb) x.size(0)
# 1000
# (Pdb) -1
# -1
# (Pdb) q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-77-14937a3aeb5a> in <module>()
#       6     #predict using network
#       7     #have to flatten the input here again. Not really sure why to be honest...something to to with tensor transform, but that seems needed so its not being fed a PIL
# ----> 8     y_pred=seqmodel(x.view(x.size(0), -1))
#       9     #compute loss
#      10     loss=loss_fn(y_pred,y)
#
# <ipython-input-77-14937a3aeb5a> in <module>()
#       6     #predict using network
#       7     #have to flatten the input here again. Not really sure why to be honest...something to to with tensor transform, but that seems needed so its not being fed a PIL
# ----> 8     y_pred=seqmodel(x.view(x.size(0), -1))
#       9     #compute loss
#      10     loss=loss_fn(y_pred,y)
#
# /usr/lib/python3.6/bdb.py in trace_dispatch(self, frame, event, arg)
#      49             return # None
#      50         if event == 'line':
# ---> 51             return self.dispatch_line(frame)
#      52         if event == 'call':
#      53             return self.dispatch_call(frame, arg)
#
# /usr/lib/python3.6/bdb.py in dispatch_line(self, frame)
#      68         if self.stop_here(frame) or self.break_here(frame):
#      69             self.user_line(frame)
# ---> 70             if self.quitting: raise BdbQuit
#      71         return self.trace_dispatch
#      72
#
# BdbQuit:
